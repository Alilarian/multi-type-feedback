# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
koz_correction_entropy = np.load("mcmc_results/kozachenko_entropies_corrections.npy")
koz_preferences_entropy = np.load("mcmc_results/kozachenko_entropies_preferences.npy")
plt.plot(koz_preferences_entropy)
plt.plot(koz_correction_entropy)

# %%
# Out:
# array([-24.26586914, -24.43481445, -24.60467529, -24.75598907,
#        -24.99491501, -25.21919441, -25.44295311, -25.72730064,
#        -25.9788456 , -26.23755836])

# %%
np.load("mcmc_results/entropies_corrections.npy")
# Out:
# array([-3.85306796, -4.74422362, -4.25115874, -4.23246871, -4.00240771,
#        -5.39016357, -4.75881718, -5.28889594, -4.82971363, -4.63481028])

# %%
np.load("mcmc_results/entropies_preferences.npy")
# Out:
# array([-7.07952968, -4.4568983 , -4.92465177, -4.66315065, -6.22748161,
#        -4.83164737, -4.80777779, -5.17447065, -6.70010098, -5.12894436])
